# %%
import numpy as np
import pandas as pd
import os, itertools, csv
from bs4 import BeautifulSoup
import re
from pytrends.request import TrendReq
from datetime import *
import time
import nltk

# load the dataset
df = pd.read_csv('./data/train.csv')
df.head()
# Out:
#    Id  Popularity                                       Page content
# 0   0          -1  <html><head><div class="article-info"> <span c...
# 1   1           1  <html><head><div class="article-info"><span cl...
# 2   2           1  <html><head><div class="article-info"><span cl...
# 3   3          -1  <html><head><div class="article-info"><span cl...
# 4   4          -1  <html><head><div class="article-info"><span cl...

# %%
def get_title(text: str) -> str:    
    soup = BeautifulSoup(text, "html.parser")
    title = soup.find('h1',{'class':'title'})
    return title.get_text()
# test
print(get_title(df['Page content'][0]))
# Out:
# NASA's Grand Challenge: Stop Asteroids From Destroying Earth

# %%
import string
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('wordnet')

#stop = nltk.corpus.stopwords.words('english')
stop = set(stopwords.words("english"))
new_words = ["\'s"] 
stop = stop.union(new_words)

def tokenizer_stem(text: str) -> list:
    tokenizer = nltk.tokenize.TreebankWordTokenizer()
    tokens = tokenizer.tokenize(text)
    
    porter = PorterStemmer()
    res = [porter.stem(token) for token in tokens if token not in stop]
    
    return " ".join(res).lower()

# test
print(tokenizer_stem(get_title(df['Page content'][0])))
headline = []
for i in range(df.shape[0]):
    headline.append(tokenizer_stem(get_title(df['Page content'][i])))
headline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yuwei\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\yuwei\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# nasa grand challeng : stop asteroid from destroy earth
# ['nasa grand challeng : stop asteroid from destroy earth',
#  "googl new open sourc patent pledg : we wo n't sue unless attack first",
#  "ballin ' : 2014 nfl draft pick get choos their own walk-out music",
#  'cameraperson fail deliv slapstick laugh',
#  'nfl star help young fan prove friendship with ador video',
#  'the underdog internet provid head washington',
#  "6-second vine video is funniest parodi iggi azalea 'fanci '",
#  'bill cosbi still plan perform comedi show florida',
#  'vend machin use cloud technolog person your purchas',
#  "onlin subscrib up , advertis still down 'new york time '",
#  'saturn photobomb moon dramat celesti moment',
#  "if caricatur artist anim 'mad men '",
#  'uber suspend oper nevada rule',
#  'appl new spaceship campu could cost $ 5 billion build',
#  "women world cup : team usa drawn 'group death '",
#  "thi is how 'go-around ' avoid disast airport",
#  'nhtsa site will tell you if your car ha been recal',
#  "unconvent way open wine bottl , when you 're desper",
#  '5 argument against net neutral',
#  'good riddanc : motorola result drag googl q4',
#  'appl publish first transpar report , transpar is bare allow',
#  "rank most popular charact 'game throne '",
#  'astronaut celebr easter space ( easter egg includ )',
#  'ukrain prime minist resign parliament scrap anti-protest law',
#  'what is hope ? alex trebek is bring back hi mustach',
#  'job open tech pricelin , defi media more',
#  "watch 'mad men ' roger sterl best bad boy moment",
#  'instagram ’ big mysteri event : what expect',
#  'if we want more ada lovelac , we need empow women',
#  'nobel prize winner malala yousafzai most inspir moment',
#  'the most glamor , booty-shak bar mitzvah perform ever',
#  'credo mobil publish industri first transpar report',
#  'robot learn gentli touch object',
#  'interact tool reveal fascin fact about your u.s. senat',
#  '100 terribl band name that should never leav garag',
#  'nba star secret score shoe endors via twitter ? beg',
#  'how optim your market real time',
#  'thousand climat activist flood wall street protest',
#  "australian journalist criticis touch mh17 victim ' belong",
#  "thi danc babi is bring 'gangnam style ' back",
#  'she back : rihanna return instagram 6-month absenc',
#  'marissa mayer thrive off never-end to-do list',
#  'nba give basketbal nerd gift big data',
#  '100 most power moment 2013 photo',
#  "miley cyru lead 'time ' person year poll , but is rig ?",
#  'will 3d print upend fashion like napster crippl music industri ?',
#  "'basebal best fan ' account shame cardin support",
#  'american apparel strike market gold sochi',
#  "leap motion can track your finger , even when it ca n't see them",
#  "batman prepar battl scarecrow 'arkham knight ' trailer",
#  'samsung galaxi gear come sept. 4',
#  'soni exec plane divert after hacker bomb threat twitter',
#  "eu want 'right be forgotten , ' but internet never forget",
#  '6 realli deep moment jaden willow smith bizarr interview',
#  'notori yemeni bomb maker loom behind latest airlin threat',
#  'iphon user go more first date',
#  'the peopl tri put camden back togeth gun tear it apart',
#  'puppycam featur futur servic dog disabl veteran',
#  'the myo armband can make googl glass truli hands-fre',
#  'what went wrong aboard sunken south korean ferri',
#  'when hollywood turn asperg into joke',
#  'half all activ twitter user live five countri',
#  'where ad exec confess their darkest work secret',
#  'nba becom first sport leagu put it twitter handl everi game ball',
#  'watch live : the first solar eclips 2014',
#  'the 7 best realiti show netflix',
#  'giveforward founder answer reader question via live chat',
#  'whi one gop veteran thought obama got extra twitter charact',
#  'intuit weather app is love free',
#  "top 8 thing you 'll miss about classic myspac",
#  'senior employe are firm biggest cybersecur weak',
#  'in oso , everyon is affect deadli mudslid',
#  'pentagon : north korea like seek foreign help with cyberwarfar',
#  "amazon offer 'greatest hit ' packag android app free",
#  '25 top mashabl resourc week',
#  '15 new york comic con cosplay bizarr take break',
#  'pirat bay co-found want build nsa-proof messag app',
#  "the 4 type 'game throne ' fan",
#  'fail kickstart forc nyc opera file bankruptci',
#  'emigr britain : where uk citizen live european union ?',
#  '10 free road trip app smooth vacat',
#  'pebbl smart watch final get runkeep app',
#  'world : we have lost first webpage. professor : oh , i have copi it here',
#  "captiv time laps show bird's-ey view warsaw",
#  'ancient penguin were roughli size lebron jame',
#  'are facebook ad work ? the click say ye',
#  'hyundai ad make light suicid , ignit internet firestorm',
#  "'game throne ' dubstep remix is cover fit king",
#  'brazilian hacker hit 14 nasa websit',
#  'facebook , pinterest , box team up mentorship program women tech',
#  'there reason nbc will stream everi second winter olymp',
#  "'mockingjay ' box offic best year , worst franchis",
#  'obama author u.s. airstrik against islam milit iraq',
#  'how do clean instal os x maverick',
#  'how connect with top influenc your industri',
#  'queensland becom flood water park guy backstrok',
#  'archaeologist find ancient puppi paw print roman tile',
#  "'templ run 2 ' is necessari beauti",
#  'chill nasa imag show white-out winter storm from space',
#  'noth wa same : drake get prayer hand emoji tattoo',
#  "'dazzl , ' brilliant , ' 'thunder ' : 14 icon film play mike nichol",
#  "'odd are thi is not ebola ' : offici test patient with ebola-lik symptom nyc hospit",
#  'amazon fire phone : 5 camera , 3d display , built-in shop cart',
#  'steve ballmer set banish appl devic clipper',
#  'the 9 smartphon with highest trade-in valu',
#  "bill hader doe killer impress former 'snl ' castmat",
#  'what doe pride mean you ?',
#  'ice pancak size plate found scottish river',
#  '10 app help you through babi first year',
#  'directv offer program dog',
#  "vine take tv cinemax promot 'banshe ' 6-second loop",
#  'appl patent smart pen',
#  "teen ' nude photo from snapchat lead investig",
#  "intel new 'iri ' chip will make laptop much better game , video",
#  'full steam ahead : travel tech carniv launch',
#  "new 'harri potter ' book cover unveil",
#  'who who iraq crisi',
#  'chicago want to be smartest citi earth',
#  'twitter stock drop 23 % wall street question it mainstream potenti',
#  'you final stream beyoncé 5th album spotifi — 6 extra song',
#  'british tv star trick into promot fake product twitter',
#  "tesla model s is top car 2014 , 'consum report ' say",
#  'grover kid presid want your sock make world better',
#  'singular might be imposs and other new you need know',
#  'your bodi odor could be your new id card',
#  'u.s. soccer made perfect landon donovan tribut video',
#  'googl ink deal with novarti make smart contact lens',
#  'aquatop turn your bathtub into interact touch devic',
#  'univers parent founder answer question via live chat',
#  'babi goat stamped will brighten even bleakest monday',
#  'hand with first screen-less waterproof iphon 5 case',
#  'thi film could turn your smartphon into solar panel',
#  'automatt , maker wordpress , acquir longread',
#  '26 diy halloween costum you can creat with cardboard',
#  'airlin waiv fee chang ticket hawaii storm approach',
#  'googl secret weapon android tv : game',
#  'youtub app will soon let you watch video offlin',
#  'what more ador than 1 babi turtl ? 150 babi turtl .',
#  "'he need some love ' : famili dog found aliv mudslid rubbl",
#  'ex-tabloid editor found guilti hack phone',
#  "nfl player declar dead wikipedia wake 'in heaven '",
#  'soldier surpris return creat best famili beach day ever',
#  'appl debut it lowest-pr imac',
#  'shaq lip sync beyonc better than beyonc',
#  'everyth you need know about new pinterest',
#  'a realli , realli excit dog faint after reunit with owner',
#  '2 cnn produc arrest tri break into wtc',
#  'twitter now speak lolcat',
#  '7 smartphon photographi tip enviabl instagram photo',
#  'all aboard ! 12 beauti railway station from around world',
#  'first day wimbledon serv up victori , upset',
#  "world cup highlight differ between 'real time ' facebook , twitter",
#  'dramat great dane struggl with take turn',
#  'colleg basebal team take videobomb gloriou new height',
#  '15 hilari quot unasham loner',
#  "it war rule world 'dawn planet ape '",
#  'amazon launch 2 origin seri with free episod',
#  "colin farrel , taylor kitsch could star 'true detect ' season 2",
#  "anthoni weiner spent absurd sum 'investig ' hi own sext",
#  'south africa rememb nelson mandela one year death',
#  'nfl make play with microsoft surfac tablet field',
#  'sgt. bow bergdahl seen smile with taliban leader twitter pic',
#  '9 surprisingli creepi quot from ban book',
#  'listen : argument from today gay marriag suprem court case',
#  '10 top case your nook hd+',
#  'is mark zuckerberg liber conserv ?',
#  'bieber ask rob ford if he brought crack club , report say',
#  "20 anim so ugli they 're cute",
#  'justin bieber pass ladi gaga most-follow twitter',
#  'global warm had key role california drought , eastern cold : studi',
#  '10 hot market job time inc. , nbc univers more',
#  'homeland secur : silk road vendor sent obama ricin letter',
#  'newark airport termin c get lot high-tech',
#  'thi real life superhero will make your palm sweat',
#  'what , editor mad magazin worri ?',
#  "'brutal tough deepli troubl ' : gm ceo mari barra face recal grill",
#  'pussi riot concert cast doubt pop music marriag with activ',
#  "if 'tetri ' becom movi , hollywood realli is out idea",
#  "'survivor ' sneak peek : jeff probst help hungri hungri hunahpu",
#  'damon lindelof goe hyster twitter rant against bieber hat',
#  'soni disabl some psn featur europ playstat 4 launch',
#  'listen music bed without disturb your partner',
#  'the morn : how newspap front page cover gop victori',
#  "hulu 'the wrong man ' is so right",
#  'ashley wagner angri face inspir olymp meme',
#  "robin thick need hug : watch him pine over ex sad 'get her back '",
#  'tobia funk act demo reel is what dream are made',
#  'babi jumpsuit report nighttim activ level',
#  'parent see their youngest children smaller than they actual are',
#  'new york citi final get .nyc domain',
#  'appl holiday quarter : by number',
#  '5 common brand messag mistak market',
#  'there better way board airplan',
#  'moto hint : a good bluetooth earbud right smartphon',
#  'australia oldest prime minist die 98',
#  "iranian 'happi ' dancer each get 'suspend sentenc ' prison time , 91 lash",
#  "facebook home hit 'about 1 million ' download , look futur",
#  'mobil advertis project increas 64 % 2014',
#  "vine loop do n't mean what you think they mean",
#  'pricegrabb acquir fashion app snapett',
#  'california track enact nation first statewid plastic bag ban',
#  '9 app resourc learn american sign languag',
#  'dicycl : the scooter get hip upgrad',
#  'put some cloth on , creepi sleepwalk statu',
#  'kermit frog kickass vacat 15 epic photo',
#  'how two fashion colleg friend reinvent onlin shop experi',
#  'politician celebr valentin day with cheesi tweet',
#  'the heartble effect : password servic are have moment',
#  'kerri syria : presid obama is not ask america go war',
#  'chart dump number ice bucket challeng',
#  "new 'mad max : furi road ' trailer crank action",
#  'how footprint recognit softwar can revolution zoolog',
#  '21 hors that are realli excit about chines new year',
#  'st. lucia : how one man went from choirboy electropop frontman',
#  'toyota new minivan make it easier parent yell their kid',
#  'american want futur tech , just not drone , implant humanoid robot : studi',
#  'whi ice storm south is such big deal',
#  'let tarot card choos your next parti sxsw thi year',
#  '$ 25 raspberri pi come u.s. , sell out hour',
#  'appl debut new retina macbook pro line',
#  'a veri special christma warn from nsa',
#  '4 tip move from your first post-grad job',
#  'the internet key regul is net neutral warpath',
#  'what connect andrew wk ian somerhald ? grumpi cat .',
#  'exclus : pandora deepen it integr with facebook',
#  'cat destroy christma tree enough ruin everyon holiday',
#  'ferguson librari offer hope commun rattl violenc',
#  'secret rule grant obama power order pre-empt cyberstrik',
#  'dogecoin power jamaican bobsl team sochi olymp',
#  "hugh bonnevil defend 'downton ' dog storylin , deni isi connect",
#  'the app that chang fashion week',
#  'iphon dock smoke alarm alert you dure sleep',
#  'tv ad launch medic marijuana',
#  'the race build tallest stand tower human',
#  "'american top 40 ' host casey kasem die 82",
#  '5 phone charg myth , debunk',
#  '12 creativ use jelli , hot new q & a app',
#  'thousand children orphan west africa ’ ebola crisi',
#  '25 diy wrap paper idea gift beauti tear open',
#  'the best moment art basel miami beach',
#  "social experi turn stranger ' email into handwritten note",
#  'student maul death white tiger indian zoo',
#  "'homeless ' man versu businessman experi prove judgment side human natur",
#  'which stunner year best soccer goal ?',
#  "what cast 'twin peak ' look like now",
#  'rodent robot sex help scientist studi evolut',
#  '10 heartwarm craigslist miss connect',
#  'rememb when nokia also made paper , galosh ga mask ?',
#  'the 12 most pain moment world cup so far',
#  'now not time fur : banecat rule litter box shadow',
#  "'grand theft auto v ' offer free multiplay onlin game",
#  'march mad slam dunk thi week social tv rank',
#  "'beyonc think piec ' hashtag mock media reaction album",
#  '350-pound high school run back is freak natur',
#  "10 classic scene photobomb 'in way guy '",
#  '3 comic help you procrastin until graduat',
#  'microsoft charg googl read your love letter',
#  'stand improv group collabor , research say',
#  'custom-engin bicycl hit 80 mile per hour',
#  'justin timberlak new co-own audio tech compani',
#  'googl glass short film deliv move mother day messag',
#  'should russia still get host 2018 world cup ?',
#  'directv get frosti respons after drop the weather channel',
#  "'the guardian ' is move new domain",
#  '23 time celeb master shruggi',
#  'nasdaq fine $ 10 million handl facebook ipo',
#  'tourist scam watch out thi summer',
#  'scientist identifi when innoc bacteria becam flesh-eat horror',
#  '3d headset treadmil combo make video game feel real',
#  'shutl pledg help retail take amazon with same-day deliveri',
#  '2013 webbi award winner announc',
#  'facebook roll out graph search u.s. english user',
#  'with bagpip bobblehead , rob ford kick off re-elect campaign',
#  'innoc lost : littl boy realiz he eat anim dinner',
#  'u.s. armi hyperson space weapon destroy second after liftoff',
#  'china now ha 300 million 3g subscrib',
#  'remain first u.s. ebola patient will be cremat',
#  'classic disney poster get serious modern makeov',
#  'the import cultiv custom relationship',
#  'appl : some iphon 5s devic have batteri bug',
#  'will ferrel ryan gosl sell knive qvc , jimmi kimmel ruin it',
#  'photo reveal univers oldest known star',
#  'massiv drill bit nearli skewer new yorker pack subway car',
#  'samsung unveil galaxi note 3 sept. 4',
#  '5 market gig you can do from home',
#  'freelanc , break free bill hour',
#  '4 month 3 million comment later , public ha spoken net neutral',
#  'obama shake hand with cuba raul castro mandela memori',
#  'foodfan offer discount restaur without fine print',
#  "ron burgundi from 'anchorman ' write memoir",
#  "9 ya book read if you love 'the fault our star '",
#  'man fatal shot after gp take him wrong hous',
#  "samsung 'veri puzzl ' galaxi s5 launch earli korea",
#  'sheryl sandberg may testifi antitrust case',
#  'what super bowl blackout look like control room',
#  'silli u.s. law come aliv thi photo seri',
#  'more michael brown document releas , key interview still miss',
#  "teenag you will melt backstreet boy 'harlem shake '",
#  'how netflix is domin australia from abroad',
#  'tumblr partner will now scan photo clue about brand affili',
#  "jessica alba shine through facial scar 'sin citi ' poster",
#  '10 game world record that put your high score shame',
#  'kid share their wise thought grumpi cat',
#  'thi radioact element could power planet',
#  'wearabl transmitt turn your palm into touch interfac',
#  '17 worst selfi 2014',
#  'amazon first fire phone ad is all about content',
#  'microsoft end support window xp',
#  'the question potenti employ want ask interview',
#  'godzilla is tech rampag',
#  "the window start menu wo n't return until 2015",
#  'proof dick van dyke still ha sens humor',
#  'matthew mcconaughey celebr matthew mcconaughey',
#  'can you make through thi entir video ?',
#  'iphon 5 vanquish samsung galaxi s4 drop test',
#  'classic meet savvi thi entrepreneur brooklyn apart',
#  "'do n't cri me argentina ' tweet soar 33,000 sinc world cup final",
#  'whi it too earli talk about ray rice redempt',
#  'clueless laker fan are pump their team made nba final',
#  'stadium vendor fire bring snow cone bathroom',
#  'power video ask you imagin world without hate',
#  'microsoft surfac 2 : a better tablet , but is it good enough ?',
#  'antar rocket ace first test flight',
#  'coupl definit , mayb break up use onli movi titl',
#  'compani offer $ 30,000 diamond-encrust appl watch preorder',
#  'ferrari hate deadmau5 nyan cat car , send ceas and desist',
#  'onlin flu track not substitut shutdown cdc',
#  "the 'first tablet women ' is aw it sound",
#  "if ray rice never play , pleas n't credit ethic",
#  'sxsw crash victim treat privat concert her hospit room',
#  'the futur email : the internet least excit applic',
#  'pinterest beef up search tool recip pin',
#  'buzzi take sting out shot',
#  'sorri , you miss your chanc buy georg w. bush artwork pillow',
#  'new york time add audienc develop posit it masthead',
#  "warner bros. take you behind brick 'the lego movi '",
#  'appl earn other new you need know',
#  'toni award nomin embrac celebr , work inspir film',
#  'how scientist plan farm mar',
#  "watch newli discov footag steve job ' first public mac demo",
#  'mobli media buy social media platform pheed',
#  'here what you miss 2013 mtv movi award gif',
#  'obama meet apollo 11 astronaut mark moon land 45th anniversari',
#  '5 way samsung galaxi s iv can beat iphon',
#  "that monster chase you new 'templ run ' is closer than you think",
#  'astrophysicist invent $ 110 earthquak warn system',
#  "sink into fiona appl eeri theme song showtim 'the affair '",
#  "stop say soni hack public hoax 'the interview '",
#  'googl heavili outspend tech rival lobbi',
#  'watch thi guy rip through 38 metal cover classic game tune',
#  'fbi spi suspect crimin hack into comput',
#  'pro-russian rebel leader give malaysian mh17 black box',
#  'human jukebox sing 14 music genr 3 minut',
#  'as d-day loom , american soldier romanc hyde park',
#  'outlook.com roll out new featur , look more like gmail',
#  "the entir 'lord ring ' trilog 90 second",
#  'finalist show off their citi becom 2020 olymp host',
#  'googl doodl pay tribut opera singer maria calla',
#  'dark gaza after isra bomb power plant',
#  '10 type imag boost your social media engag',
#  'how christian observ good friday around world',
#  'great scott ! a hoverboard futur is final here',
#  "5 way hbo 'silicon valley ' is just like real thing",
#  'disney buy up $ 8 billion stock start next year',
#  'esur super bowl twitter contest got 200,000 entri one minut',
#  'iranian hacker use fake social media account espionag',
#  'u.s. carrier ralli around blackberri 10',
#  'samsung nx3000 camera let you get seriou about selfi',
#  'your tumblr dashboard just got sexier',
#  'research teleport 10,000 bit inform 1 second',
#  'how minim risk when crowdfund kickstart',
#  '10 robust starbuck mermaid makeov',
#  'appl will launch curv iwatch octob , report say',
#  'activist pressur target keep rifl out it store',
#  "hotel associ take aim airbnb , but airbnb is n't take bait",
#  'glanc turn almost ani wrist gear into smart devic',
#  "'befre ' text shortcod help victim human traffick",
#  'opera max is littl app that save your bandwidth',
#  'memini is wearabl camera that captur moment after they happen',
#  'turn your facebook timelin into actual book with likebook',
#  'toni hawk still king halfpip 46',
#  'is twub next big twitter chat manag tool ?',
#  '15 creativ way repurpos your old beer can',
#  'what most retweet tweet all time say about twitter',
#  'robot search sunken world war ii aircraft',
#  'googl introduc tool calcul mobil roi',
#  'samsung shape : right way do wi-fi speaker',
#  "j.j. abram lament 'star war ' set photo 'star war ' set photo",
#  'republican , democrat final find common ground — on code',
#  '8 question about debt ceil deal you should know how answer',
#  'bill gate host reddit ama',
#  'ask a dev : how add real-tim updat your app',
#  'watch how astronaut sleep space',
#  "obama veteran affair misconduct : ' i will not toler it , period '",
#  'top 10 brand social media 2013',
#  "googl new shut spain 'googl tax '",
#  'appl retir apertur photo app thi fall',
#  '15 pinterest board your dad would actual be interest in',
#  'celebr read mean tweet about themselv ( round 3 )',
#  'i drove 3d print car',
#  'it now easier travel across u.s. bu',
#  'galaxi gear , galaxi note 3 galaxi note 10.1 hit u.s. in octob',
#  'facebook messeng hack reveal mobil payment servic',
#  'teen are breed ground meningitis-caus bacteria , liter',
#  'first 100 gener internet domain includ .rich , .sexi .ninja',
#  'tumblr make first appear befor suprem court',
#  "miley cyru flame lip cover the beatl ' ' a day life '",
#  'see all oscar night twitter activ 50 second',
#  "asu ' new zenbook infin other new you need know",
#  'soccer star cristiano ronaldo throw atroci first pitch',
#  "taylor swift '22 ' parodi poke fun tinder app",
#  'zynga founder mark pincu step down day-to-day role',
#  "10 place you ca n't use googl glass",
#  '8 babi name after internet tech',
#  'ukrain presid set deadlin pro-russia milit disarm',
#  "elon musk vs. the time : whi thi ca n't end well tesla",
#  "taylor swift open ama fieri 'blank space ' perform",
#  'googl under ftc investig other new you need know',
#  'fight jet lag with thi wearabl light',
#  'appl stock fall below $ 400 for first time sinc decemb 2011',
#  'googl adopt 7 new tech hub north america',
#  'energi secretari is so readi throw first pitch fenway',
#  'design reimagin googl glass fashion eyewear',
#  'whi satya nadella is too safe choic microsoft ceo',
#  'taylor swift think jimmi kimmel is jerk',
#  'profession share tip trick freelanc success',
#  '5 chart break facebook $ 3 billion third quarter',
#  'nuanc app read new articl out loud while you drive',
#  'putin latest law forc russian blogger regist with govern',
#  '12 weirdest pizza order teenag mutant ninja turtl',
#  'appl hire fashion-focus store staff appl watch launch , report say',
#  'build app ? ask develop your vital question',
#  "feel 'tension ' jimmi fallon carol burnett lost soap opera",
#  "'assassin creed uniti ' : glitch microtransact mar pretti pari",
#  "listen winner from golden globe : adel 'life pi '",
#  "'break bad ' star send emot last tweet befor seri final",
#  'microsoft post record revenu $ 21.5 billion decemb quarter',
#  'california want compani disclos everyth they know about you',
#  "did n't enjoy your hotel stay ? that 'll be $ 500 , pleas",
#  'who in , who out obama meet tech exec ?',
#  'what best car escap horrif monster attack ?',
#  'littl girl make compel case read book',
#  'microsoft backtrack xbox one drm use game polici',
#  'high plain burn up record heat wave bake area',
#  "becaus ipad , 'littl mermaid ' will never be same",
#  "twitter data show when we 're happi , sad , hungov",
#  'man make music by electrocut veget',
#  '17 impress dad whose reflex save day',
#  'job hunt ? 220+ open the world bank , crain more',
#  "pixar reveal new 'monster univers ' mother day teaser",
#  'the weather channel agre directv term',
#  'digit & tv ‘ doubl coverag ’ key super bowl market success',
#  'search miss malaysian plane prove how much trash is our ocean',
#  'twitter instal two log cabin it san francisco headquart',
#  'china want man moon mission , expert say',
#  "'the voic ' crown winner , n't one expect",
#  '8 fundament internet lesson teach kid',
#  'hundr rememb jame foley hometown church',
#  'polar bear shut down halloween northern canada commun',
#  'follow honey : can save bee track them ?',
#  'japan want resum whale hunt',
#  'facebook cut down twitter vine',
#  'waterg editor ben bradle die 93',
#  'is verizon realli slow down netflix ?',
#  "'save by bell ' actor dustin diamond arrest alleg stab",
#  'dear obama : funer are no place selfi',
#  'amazon fire phone free unlimit photo storag : open abus ?',
#  'redesign ford mustang take you back 1969',
#  'fear make scari scent stronger',
#  'thi is man who made grumpi cat rich',
#  "digit holdout 'harper ' magazin launch it first app",
#  'new aerial imag show boston bomb suspect in boat',
#  '21 time journalist have confirm mask troop crimea are russian',
#  'american onli use half their paid vacat',
#  'st. loui cardin fan hurl racist insult ferguson protestor',
#  'how mobil phone can help beat malaria',
#  'prompt drought , california will regul groundwat first time',
#  "'the newsroom ' final stay true seri — good bad",
#  "appl video highlight app peopl ca n't live without",
#  'xbox will shutter it entertain branch amid massiv layoff',
#  'meme turn miguel herrera into super saiyan world cup',
#  'new high-r telescop captur stun photo andromeda galaxi',
#  'yemen al-qaeda threaten kill us hostag',
#  'tsa confisc record number firearm past year',
#  'new tool promis predict whether your video will go viral',
#  "19 import lesson 'america next top model '",
#  'music monday : appl wwdc 2013 edit',
#  '10 way mashabl reader unplug',
#  'storm chaser describ long night rescu after arkansa tornado',
#  "whi everyon thought there were 'multipl shooter ' ottawa",
#  'youtub cram everi big internet moment year insan mashup',
#  'what elvi presley do nfl sidelin ?',
#  'whi appl unveil 2 iphon thi year',
#  "zachari levi 'sesam street ' want you unplug go outsid",
#  'soni smartwatch 3 is all about voic control',
#  '5 home secur tip frequent travel',
#  'how singl cat spend valentin day',
#  'googl launch standalon doc sheet app io android',
#  'is darpa atla robot real-lif termin ?',
#  "twitter co-found channel poe 'raven ' 'evermor ' short film",
#  'how halt facebook hoax',
#  'whi moto 360 smartwatch will kill googl glass',
#  'tweet travel innov win trip austin',
#  'smart glass reveal what it like have superpow',
#  'can facebook put video ad new feed without anger user ?',
#  'tile tracker with io app help you find lost belong',
#  '23 kid reveal their secret mom',
#  'whi presid almost never apolog war',
#  '20 thing david bowi discov befor you',
#  'the armi is test cut edg , halo-lik helmet',
#  "u.s. reportedli built 'cuban twitter ' undermin castro govern",
#  'win your friend 2 vip ticket social media day',
#  'how googl glass will chang porn',
#  "nsa can 'easili ' break cellphon encrypt , report say",
#  'daytona 500 delay extrem weather',
#  'white hous secur offici fire over controversi tweet',
#  'world cup day 23 : contin clash first round quarterfin',
#  'how bad could it get ? 5 worst-cas scenario iraq',
#  'korean basebal team unveil robot avatar absent fan',
#  'jame mcbride join mashabl social book club',
#  'how 12 busi leader got c-suit',
#  '6 labor-sav gadget life leisur',
#  'gold-back bitcoin spinoff aim keep some fun virtual currenc',
#  "see actor aaron paul nail hi 'break bad ' audit",
#  'what do with your new playstat 4',
#  'uncl sam make creepi cameo bizarr anti-obamacar ad',
#  "in one line , 'the walk dead ' made viewer deepli dislik one charact",
#  'barn & nobl offer sneak peek samsung/nook tablet — with grumpi cat',
#  'blackberri rise report compani may go privat',
#  "get nostalg with ghost beach '90 playlist",
#  '8 gift techi everyth',
#  'social site famili : more person facebook',
#  'appl latest acquisit point futur wearabl gadget',
#  'appl ibm partnership bear first fruit : 10 enterpris app',
#  'how xbox chang it look through age',
#  'london student discov explod star nearbi galaxi',
#  'appl crack fortun 500 top 5 first time',
#  "pokémon vs. presid : got ta name 'em all",
#  'vint cerf warn against evil superpow take over internet',
#  '2 skier pull best high five bro histori',
#  "pitbul kesha premier sexi 'timber ' music video facebook",
#  'let govern scientist tweet more , report say',
#  'iran will start elimin nuclear stockpil jan. 20',
#  'the immigr reform debat : who want ?',
#  'british compani reunit lost teddi bear owner',
#  'learn kickstart freelanc career # bizchat twitter chat',
#  'shakespear shatner go head-to-head lego film',
#  "disney 'fantasia ' game will rock your world",
#  'whi employ could now immedi deni you all birth control coverag',
#  'googl mysteri barg combust death trap , report say',
#  "kia super bowl ad unleash power 'the matrix '",
#  "larri page : tech is 'not zero-sum game '",
#  "retail turn 'showroom ' into innov opportun",
#  'thi week greatest moment 23 photo',
#  'mlb star roast comment who blame him horrif injuri',
#  'a sigh relief , urban outfitt is not world biggest seller vinyl',
#  '17 peopl awkward holiday',
#  'protest ralli net neutral 20 u.s. citi',
#  '55 colleg univers face feder investig sexual assault case',
#  'twitter mobil app updat highlight trend tv show',
#  'creativ ( satisfact ) take hit when you watch clock',
#  'jawbon up3 sleeker , smaller , smarter fit tracker',
#  "rais your glass 'mad men ' drink game",
#  "ferguson polic ban from wear `` i darren wilson '' bracelet",
#  '10 best user follow vine',
#  'uk spi agenc yahoo webcam spi : what you need to know',
#  'how check if hacker stole your data massiv target breach',
#  'bit.li media map show most share new each state',
#  'tip solv your sequest flight delay woe',
#  'the strang saga nfl alum quest onlin justic',
#  '10 fascin data visual project',
#  "nasa astronaut discuss 'orbit perspect ' google+ hangout",
#  "now bullet wo n't break 3d-print gun",
#  "'looper ' director rian johnson take 'star war : episod viii '",
#  '9 holiday gift idea your teen',
#  'even sport star get salti about be unfollow twitter',
#  '7 social media facepalm you should never repeat',
#  '19 sunset from uniqu perspect',
#  'will public radio surviv music stream app ?',
#  'day app will chang how you share photo with friend',
#  'whi is employe moral declin ? blame improv economi',
#  'u.s. hous major leader eric cantor defeat massiv upset',
#  'sperm donor want : uk govern seek address shortag',
#  'the futur googl fiber : whi search giant is bet broadband',
#  'blackberri z10 smartphon alreadi go $ 1,500 ebay',
#  '2014 world cup will be first use goal-lin technolog',
#  '41 song that keep heat wave go',
#  'dad year decid babi need facial hair',
#  'budweis crack open music scene with facebook , vice',
#  'foursquar open up advertis all busi',
#  'the complet guid tumblr subcultur',
#  'geniu bear steal entir dumpster from restaur',
#  'ugli nfl bulli scandal leav disturb digit trail',
#  'surgeon have identifi ideal femal belli button',
#  'tini batman take whimsic trip through american southwest',
#  '11 time bill nye taught you scienc is awesom',
#  'tnt launch sequel second most-shar ad all time',
#  'kid presid send heartfelt mother day salut mom',
#  'some comed geniu photobomb kim jong-un nobodi notic',
#  'watch : rosetta spacecraft meet comet',
#  'report : samsung unveil galaxi s5 feb. 24',
#  'imgur updat gif format load much faster',
#  'thi bluetooth ring is like magic wand your finger',
#  "oxford dictionari honor 'vape ' word year 2014",
#  'solepow shoe insol charg your phone while you walk',
#  'south korean ferri captain sentenc 36 year prison',
#  'qualcomm buttonless toq smartwatch slate dec. 2 debut',
#  'soni samsung escal 4k war best buy',
#  '17 music lyric express your internet struggl',
#  'u2 releas first studio album 5 year appl event — it free',
#  "we would n't ask you read stori about bond unless it wa import",
#  'solar storm near peak could caus vivid northern light display',
#  'proof facebook privaci problem : mark zuckerberg privat friend list',
#  "bill murray , jake gyllenha test limit 'antihero ' toronto film fest",
#  'wristwatch use declar jfk time death may sell $ 100,000',
#  'steve wozniak diss ipad air',
#  'latest isi captiv is peter kassig , former u.s. soldier',
#  'stackmot is green screen app your camera roll',
#  '5 social media tactic increas roi',
#  'funni or die steve job mockumentari think differ',
#  "15 geeki easter egg you 'll want poach",
#  'ukrain militari launch fierc assault against pro-russian rebel',
#  'boston bomb : truth , justic wild west social media',
#  "hbo 'girl ' are basic your friend ... facebook",
#  '18 best jimmi fallon moment 2014',
#  '30 song fuel your summer vacat',
#  'microsoft air first surfac pro commerci dure grammi',
#  'beat music come ipad',
#  'a complet guid jimmi kimmel kany west bizarr twitter feud',
#  '28 enchant instrument song , accord reddit',
#  'tesla open first plant netherland',
#  'the 10 countri with fastest internet',
#  'canon rebel sl1 : the world smallest dslr camera',
#  'first u.s. bitcoin vend machin instal new mexico cigar shop',
#  'microsoft hire young design whose rebrand project went viral',
#  'if walter white carri purs , it would probabl look like thi',
#  'a thing consid dress dog halloween',
#  "appl custom ' verdict new product : a mix bag",
#  '10 reason you should stop complain about babi photo facebook',
#  'u.s. may allow cellphon call dure flight',
#  'map juli 4 tweet show twitter had it own firework show',
#  'tumblr android get facelift',
#  "syrian electron armi : if u.s. attack 'we will target all it '",
#  'can social media whiz help thi cheesemong ?',
#  "if georg r.r. martin wrote 'mad men '",
#  'lexu reveal two new model vine',
#  "donna from 'that 70 show ' predict her incarcer futur",
#  'new pope fail beat obama twitter record',
#  'beyonc , jay z confirm summer tour : a map their perform',
#  "kesha unleash music video ' c'mon '",
#  'youtub 20 most-shar ad march',
#  'spock imperson logic decid not prosper porn',
#  "research reveal how kid learn from 'sex-satur ' onlin cultur",
#  "'man steel ' debut sinist new trailer featur gener zod",
#  'is clip articl fair use ? u.s. court say no',
#  'ecommerc site let you search cloth upload photo',
#  "brad paisley defend 'accident racist ' twitter",
#  'pocket-s charger claim keep your devic juic up',
#  'microsoft : window blue come 2013 with small-screen support',
#  'googl glass prescript eyewear photo leak onlin',
#  "new 'man steel ' trailer promis summer hit",
#  '13 app best glastonburi festiv experi',
#  'most earth-lik alien planet discov',
#  'in pictur , worldwid protest against isra militari action gaza',
#  'fist bump spread fewer germ than handshak , studi say',
#  'polic investig racist tweet aim manchest citi yaya touré',
#  "'pardon edward snowden ' petit reach 100,000-signatur threshold",
#  'rage know no age : edm grandma parti hard surpris zedd concert',
#  'hide secret messag facebook photo with thi chrome extens',
#  'iron , anonym app secret is hatch irl meetup',
#  'the 20-year evolut playstat hardwar',
#  "'biggest refuge crisi age ' brace brutal winter",
#  'usa vs. mexico : what you need know wednesday world cup tuneup',
#  'amazon light up game with fire tv : $ 40 control could rival consol',
#  'how googl glass could help peopl with parkinson',
#  'bloomberg media make first move toward new digit product',
#  'comcast subscrib can soon watch tv via twitter',
#  'tastiest vine all time : ryan gosl refus cereal',
#  'millenni , here how prep quit your job',
#  'drone beat : obama execut order , 20-minut rescu more',
#  "jacki collin perform dramat read cher 'woman world '",
#  "'jew arab refus be enemi , ' unit peac amid gaza conflict",
#  "'sleepi hollow ' kill sophomor slump worri with season premier",
#  'studi : googl , facebook among toughest job interview',
#  'captur instagram that embodi product',
#  '12 uncanni imadefac self-portrait',
#  'al wikipedia page view up 18-fold sinc ice bucket challeng',
#  'how sell your iphon 5 , 5c 5s',
#  '3 element everi success busi plan',
#  'dj greg jame mock ed sheeran , taylor swift inaugur bbc music award',
#  'samsung ipad mini altern is actual pretti good',
#  'robin william , world cup ebola top googl search 2014',
#  'two box kangaroo beat up each suburban street australia',
#  'boe 787 dreamlin return ski',
#  'facebook step up new game with save later featur',
#  'india cyclon lead blizzard nepal that leav least 27 dead',
#  'htc one launch at & t , sprint april 19',
#  'taxi driver faster , less safe uber lyft counterpart , studi find',
#  'elmor leonard 10 rule write',
#  '4 thing most success entrepreneur have common',
#  'live blog : super bowl ad',
#  'befor after : the west ha lost 63 trillion gallon water dure drought',
#  "vinc vaughn could be 'true detect ' season 2",
#  'what is bittorr ?',
#  'microsoft new window phone partner : lg lenovo',
#  'the unoffici histori unicorn',
#  'man develop oculu rift chicken',
#  'aussi thong crowdfund campaign rais $ 10,000 hour',
#  'googl pay for free wi-fi san francisco park',
#  "nike fuelband wa first fit tracker fall , but it wo n't be last",
#  'million watch alleg serial abus play raven last night',
#  'mind-bend photo seri blend model into nyc landscap',
#  "12 day 'orang ' : the ladi litchfield get holiday spirit",
#  'new steve job movi trailer arriv exclus instagram',
#  'an elf favorit instagram hashtag',
#  'get readi pay more airport secur',
#  "whi are n't we farm octopu ?",
#  "'game throne ' is most pirat show 2013 so far",
#  'the busi death : 7 compani concern with afterlif',
#  "arizona inmat pronounc dead 2 hour after 'botch execut ' began",
#  '13 bone-chil attract from around world',
#  "the latest 'simpson ' couch gag wa both insan beauti",
#  'googl chromecast will soon be littl more like appl tv',
#  'beyonc debut new song tumblr',
#  '49 hostag isi have been freed , turkish pm say',
#  'the latest version flipboard smartphon',
#  'south korean ferri : all navig crew member custodi',
#  'facebook worst-cas scenario : becom next yahoo',
#  "'sunset overdr ' fan pick game next goodi",
#  'malcolm gladwel disabl part hi brain research latest book',
#  'dutch student sell all hi person data 350 euro',
#  "watch conan o'brien 'late night ' audit from 1993",
#  'youtub announc geek week , start aug. 4',
#  'kidnapp releas video that claim show miss nigerian girl',
#  "univers collid creepi tom bradi 'wreck ball ' parodi",
#  '9 book recommend base on your favorit social media platform',
#  'sheryl sandberg becom billionair',
#  'hunt miss south korean ferri passeng hold due bad weather',
#  '16 ridicul world cup confess from ballsi fan',
#  "lawmak tri again creat 'entrepreneur visa '",
#  'job hunt ? 180+ open zappo , livestream more',
#  "stack deck with 'hous card ' play card",
#  'missouri offici detail secur plan ferguson grand juri announc',
#  'oklahoma parent panic teacher trip ebola-fre rwanda',
#  'brazil devast defeat wa most tweet sport game ever',
#  '‘ wheel fortun ’ contest troll pat sajak',
#  "'doctor who ' fan want empir state build lit up tardi blue",
#  'kid send mlb star ador letter after scari accid',
#  'earth day : get green with googl doodl',
#  'north korea say it hold american tourist',
#  "talk smack espn , yoda doe : 'thi is mad ' return",
#  '20 song turn 20 2015',
#  'how nail the social job interview',
#  'insta-diy : madesquar turn your iphon photo into craft',
#  'thi is your brain love',
#  'how taco bell is exploit snapchat stori',
#  '13 vine video bring you back your game childhood',
#  'cook yourself romant valentin day meal one',
#  "will thi accessori help googl glass ' short batteri life ?",
#  'facebook plan launch more standalon app like messeng',
#  'thi corgi get massag is all you need right now',
#  'bmw electr car reimagin loung furnitur',
#  'whi would-b marijuana mogul have their work cut out for them',
#  'dramat video show whi you should never jump onto train track',
#  'the group blogger unearth mh17 intel quicker than u.s. spi',
#  'is spider-man x-men movi team-up real ?',
#  'how reinvent your career',
#  'aereo expand cord-cut onlin tv servic atlanta',
#  'hp launch two huge smartphon india',
#  'ebola outbreak west africa now worst histori',
#  'when youtub star make movi , superfan market is bake in',
#  'teen age 7 year less than 2 minut',
#  'kid attack dad after he botch catch foul ball',
#  'dog will serious eat anyth',
#  'former nfl player name polit fellow huffington post',
#  'brilliant rainbow appear after oklahoma tornado',
#  'walmart unveil futurist truck that is fuel-effici',
#  'hundr pour new york union squar solidar ferguson',
#  'delici epic pancak art celebr nation pancak day',
#  'prost ! toast oktoberfest 2014 photo',
#  'thi drive-thru chucki doll prank is more funni than scari',
#  'david cameron refus wear feminist t-shirt',
#  "'retail jedi ' 14 other absurd job titl",
#  "hong kong leader say beij wo n't back down",
#  'microsoft hint skype call may be fair game nsa',
#  'what your state want , accord googl autocomplet',
#  'famou face lend star power new york climat protest',
#  'facebook launch redesign mobil app io 7',
#  'mean girl beauti queen : an ode real jani ian',
#  "'silicon valley ' episod 7 recap : carnal code",
#  'one less hurdl : women shelter allow victim escap pet',
#  'whi is everyon so obsess with emoji ?',
#  "when mickey mous appear 'the empir strike back '",
#  'boe 787 dreamlin use most flammabl batteri market',
#  'jay-z got 99 problem , includ zombi bite',
#  'ukrain crisi close civil war , russian foreign minist say',
#  'ancient cambodian citi reveal laser scan',
#  "'thi young man dead ' : hundr protest ny polic shoot",
#  '6 meteor shower watch for next month',
#  "uber driver stage 'global day protest '",
#  'gold iphon 5s no longer avail onlin thi month',
#  "sansa stark got 99 problem bad rap one 'game moan '",
#  'imagin new way read , one 3d-print book time',
#  '6 architectur project that revolution citi life',
#  'vine challeng : launch your own vine show',
#  'how indestruct is iron man suit ?',
#  "mccain introduc bill ' la cart ' cabl tv",
#  'samsung boost capit spend high-end phone demand slow',
#  "you ca n't javert eye latest internet meme",
#  'nba star assist fan twitter marriag propos',
#  'hennessey venom gt becom world fastest product car',
#  'shape-shift mirror deliv clearest imag space',
#  "'kill your darl ' trailer make harri potter look like muggl",
#  'first case deadli middl eastern viru found u. .',
#  'how skype is help toppl dictat syria',
#  'amazon put samsung galaxi s iii sale',
#  'yahoo answer 10 ridicul tumblr question',
#  'bacon-sc alarm app give iphon meati overhaul',
#  'paypal teas cash regist program goofi video',
#  "snowden : 'if i end up chain guantanamo i can live with that '",
#  'scientist engin bacterium with 6-letter dna',
#  "do n't miss these 25 digit media resourc",
#  'detroit file bankruptci',
#  '16 creepiest target facebook ad',
#  'the hire that could save destroy crumbl hulu',
#  "'thi is what democraci look like ' : ferguson octob photo",
#  'lenovo tab s8 : an atom-pow 8-inch tablet $ 199',
#  'googl remov 2 chrome extens that deliv spam',
#  'impress your muggl friend with magic wand tv remot',
#  "19 'game throne ' greet card kill with kind",
#  'imdb app hit 100 million download eve major upgrad',
#  'despit deal , netflix ceo blast comcast',
#  'volkswagen super bowl ad ha jamaican accent',
#  '10+ samsung galaxi s 4 case come soon',
#  'kashmiri student expel root against indian cricket team',
#  'with facial recognit partnership , match.com user can find date base exe',
#  "googl challeng 'right be forgotten ' rule europ",
#  "the twitter trap : whi tri be facebook wo n't work",
#  'mom freak out after nba player deviou taco bell prank',
#  "'largest structur univers ' discov scientist",
#  "'candi crush saga ' sequel add sticki soda equat",
#  'radioact boar still found germani decad after chernobyl',
#  'appl is fall behind smartphon game',
#  'fake instagram updat add snark filter',
#  "amc sorri spoil 'the walk dead ' facebook",
#  'nokia teas appl imit lumia with iphon 5c',
#  'portland sue uber 3 day launch citi',
#  'secret life cat reveal gp track studi',
#  'connect cultur could be bad your health',
#  'ruben studdard want serenad you person',
#  'slow-mot tattoo might perman scar your brain',
#  "'30 rock ' inspir new ben & jerri ice cream flavor",
#  "studi : vast underground 'ocean ' discov near earth core",
#  'larri ellison step down oracl ceo',
#  "' x-men : day futur past ' video suggest mutat histori",
#  "comcast ceo custom servic call hell : ' i disappoint '",
#  'creat beauti wed websit with these 6 servic',
#  'man pop question with terrifyingli romant movi trailer',
#  'into wild : googl announc zoo street view',
#  "'seeing-ey vest ' could help blind navig via vibrat",
#  'flickr crash follow massiv yahoo mail outag',
#  "netflix wo n't rais current member ' price 2 year",
#  "5 can't-miss app : autodesk sketchbook more",
#  'world smallest 3d-print pen is come kickstart',
#  '17.4 % global web traffic come through mobil',
#  '# whyweneedfrat hashtag anger feminist greek life member',
#  '4.4-magnitud earthquak rattl lo angel',
#  'snapchat updat add quicker , flashier featur',
#  "billi eichner prove new yorker do n't care about emmi",
#  'gener 8-bit parent',
#  'whatsapp add new featur let know peopl read messag',
#  "the 8 type super bowl ad you 'll see thi weekend",
#  "'termin : genisi ' get vicious scorch twitter",
#  'magician turn $ 1 into $ 100 homeless thi touch video',
#  '6 fact about golden globe statuett',
#  'the final four : your cheat sheet root guid',
#  "appl fingerprint scanner did n't alway work well",
#  '13 ridicul travel accessori no one will ever need',
#  'blackberri sold less than 2 million bb10 smartphon last quarter',
#  'straight talk iphon 5 data plan is not unlimit',
#  'where sitcom charact live new york citi',
#  'read full white hous report syria chemic attack',
#  'joan river is still life support',
#  'live updat : clash near ferguson offic kill arm black teen',
#  'it take more than 200 rubber band explod pumpkin',
#  "'candi crush ' is bigger than twitter , but probabl not for long",
#  'toyota consid build actual hover car',
#  'whi you should eat thi $ 330,000 burger',
#  'thiev pull off multi-million-dollar heist brazil samsung factori',
#  "'hero reborn ' creator tim kring reveal plan are 'ever-chang '",
#  '16 stock stuffer stoner light life',
#  "'veronica mar ' kickstart backer offer refund after download complaint",
#  "elli gould give justin timberlak 'mirror ' soul twist",
#  '12 trippi gif help stoner celebr weed legal',
#  "louisiana doe n't want ebola patient inciner wast",
#  "chri evan premier 'befor we go ' : decent direct debut , doa stori",
#  '7 common salari negoti mistak avoid',
#  "'sh*t fashion girl say ' star vie fashion job",
#  '700,000 color sheet paper cover event space',
#  'brandon knight epic nba poster fuel internet glee',
#  '10-month-old startup buy 93-year-old busi $ 100 million',
#  'chuck hagel tell tim howard he could becom defens secretari — someday',
#  'wristwatch combat sexual violenc india',
#  "u.s. journalist ashoka mukpo say he now 'ebola free '",
#  'what roi thi articl ?',
#  'valv unveil steam control with dual trackpad touchscreen',
#  'high-tech sleev is basketbal coach your arm',
#  'more than 500 million photo are share everi day',
#  "top 10 tv show twitter past year : 'break bad ' tread heavili",
#  'pari hilton new music video is veri unicorn-i',
#  'sen. rand paul live-tweet hi hours-long filibust',
#  'a song everi crazi cat person internet',
#  '60-year-old smallpox vial found unus fda storag room',
#  'the complet guid pebbl smartwatch',
#  "how 'new low ' spycraft chang ukrain sniper convers",
#  'gchat is start look much more like googl hangout',
#  'hootsuit bounc back after ddo attack',
#  '20 vine from deadli tornado outbreak',
#  'the biggest disast simciti ruin it everyon',
#  'amazon is test it own deliveri servic , report say',
#  'brad pitt angelina joli wed secret ceremoni',
#  'meet first babi born after genet embryo screen',
#  "amazon launch 'love stori ' interact map valentin day",
#  'obama play tech support healthcare.gov',
#  'chri hemsworth name peopl sexiest man aliv',
#  'chines hacker found u.s. govern data googl server',
#  "syrian electron armi hack 'the washington post '",
#  'research 3d print blood vessel into tissu artifici organ',
#  "thi is your chanc hack 'jurass park ' comput system",
#  '# makefurhistori : lush announc innov anti-fur campaign',
#  'these crazi bike trick are off chain',
#  'nik wallenda surviv insan grand canyon tightrop cross',
#  '10 dog that will break your heart , then make you smile',
#  "valv announc 'steam machin ' game pc your live room",
#  'it arriv : dj earworm epic mashup 2014 biggest pop song',
#  'softbank ceo want take over world — t-mobil is next',
#  "walmart apolog call out 'fat girl costum '",
#  "15 classic piec microsoft clip art 'll miss",
#  'arrest made after pumpkin festiv turn mayhem',
#  'flickr boost speed add hd video io android app',
#  'nest is now better distinguish smoke from steam',
#  'cartub : the best way wast time traffic',
#  'hama unmask : who are milit fight israel ?',
#  'polic : nfl player jonathan dwyer head-but wife , threw shoe babi',
#  "rhyme zombi : 'the walk dead ' meet dr. seuss",
#  "israel iron dome is 'total failur ' it most import job , expert say",
#  "comcast doe n't care about you , realli anyth",
#  "'facebook music ' hilari depict social addict",
#  'facebook now give more control over what you share',
#  "'disney infin ' is epic toy video game mashup",
#  'vine challeng : light dark',
#  'digg reader will be avail everyon june 26',
#  "die littl adam lambert queen 'somebodi love ' anthem",
#  'android vp hugo barra leav googl china xiaomi',
#  '8 imag that prove scienc is phenomen art form',
#  "netflix 'hemlock grove ' teaser reveal season 2 releas date",
#  "retail ' digit ad spend near $ 10 billion",
#  '10 feedback tool design',
#  "not into 'job ' ? mayb 'gate ' is more your style",
#  'instagram reportedli work new messag featur',
#  'microsoft updat privaci polici after access blogger hotmail',
#  'nba superstar : extrem rich , yet also underpaid',
#  'comedian awkward stage exit win emmi',
#  'oculu rift : hand on with futur game',
#  'french inventor claim pill make fart smell like chocol',
#  "activist take san francisco court over 'googl buse '",
#  'parrot introduc oculu rift-en drone',
#  'samsung expect post record $ 9.4 billion profit q3',
#  "scari ghost stori are even creepier when they 're about bill murray",
#  "aol tri new subscript bundl with pandora , 'maxim '",
#  'uk arrest 9 men counterterror oper',
#  'googl glass will get prescript lens',
#  'what tax prepar softwar look like 1991',
#  "do n't even tri have convers with thi guy",
#  'facebook , appl , googl back same-sex marriag suprem court file',
#  'now anyon can use getti stock photo free',
#  '28 incred moment photo',
#  'bose sue appl beat over noise-cancel patent',
#  "'american horror stori : freak show ' promo take you insid carniv",
#  'the wildli bizarr song fall ha arriv',
#  'the 20 startup marissa mayer ha acquir yahoo',
#  'march mad connect gener',
#  'how thought leader view import give back',
#  '23 song feed your rebelli side',
#  'hacker olymp draw top student silicon valley',
#  "mark hamil appear 'the flash , ' repris role 23 year ago",
#  'build ani robot you want , no program requir',
#  'lenovo unveil it first 8-inch window 8.1 tablet',
#  'snoopi make hi vine debut',
#  'bud light help one lucki dude have wildest night hi life',
#  'gunshot residu found vonderrit myer , st. loui teen kill polic',
#  'mark zuckerberg immort madam tussaud',
#  'amazon shave $ 20 off kindl fire hd tablet father day',
#  "daniel radcliff adam driver 'star war ' role : he 'brilliant improvis '",
#  'how sochi stack up past olymp host citi',
#  'palestinian israel accept egypt new 72-hour cease-fir propos',
#  'what happen insid investig aaron swartz',
#  "australian art director name 'australia biggest wanker ' by reddit",
#  'askem get you answer you need , fast',
#  'tour buse collid near time squar ; 14 injur',
#  ...]

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
param_C = [0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0]

#clf = LogisticRegression(random_state=0)
pipe3 = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,3))), 
                  ('clf', LogisticRegression())])

# set the param_grid parameter of GridSearchCV to a list of dictionaries
param_grid = [{'clf__C': param_C,
               'clf__solver': ['liblinear']}]
gs = GridSearchCV(estimator=pipe3, 
                  param_grid=param_grid, 
                  scoring='accuracy')

gs = gs.fit(np.array(headline), df['Popularity'])
print(gs.best_score_)
print(gs.best_params_)
# Out:
# C:\Users\yuwei\.conda\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.5270050283977861
# {'clf__C': 0.1, 'clf__solver': 'liblinear'}

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer

names = ['LogisticRegression', 
         'LogisticRegression+(1,2)gram',
         'LogisticRegression+preprocess',
         'LogisticRegression+preprocess+hash']
# without preprocessing
pipe1 = Pipeline([('vect', CountVectorizer()), 
                  ('clf', LogisticRegression(solver = "liblinear"))])
# without preprocessing, use larger ngram range
pipe2 = Pipeline([('vect', CountVectorizer(ngram_range=(1,3))), 
                  ('clf', LogisticRegression(solver = "liblinear"))])
# with preprocessing
pipe3 = Pipeline([('vect', TfidfVectorizer()), 
                  ('clf', LogisticRegression(solver = "liblinear"))])
# with preprocessing and hasing
pipe4 = Pipeline([('vect', HashingVectorizer(n_features=2**10)), 
                  ('clf', LogisticRegression(solver = "liblinear"))])

clf_labels = ['LogisticRegression', 
         'LogisticRegression+(1,2)gram',
         'LogisticRegression+preprocess',
         'LogisticRegression+preprocess+hash']
print('[Individual]')
for pipe, label in zip([pipe1, pipe2, pipe3, pipe3], clf_labels):
    scores = cross_val_score(estimator=pipe, X=np.array(headline), y=df['Popularity'], cv=10, scoring='roc_auc')
    print('%s: %.3f (+/- %.3f)' % (label, scores.mean(), scores.std()))

# CV
# print('[auc (10-fold cv)]')
# for name, clf in zip(names, [pipe1, pipe2, pipe3, pipe4]):
#     scores = cross_val_score(estimator=clf, X=np.array(headline), y=df['Popularity'], \
#                          cv=10, scoring='roc_auc')
#     print('%s: %.3f (+/-%.3f)' % (name, scores.mean(), scores.std()))
# Out:
# [Individual]
# LogisticRegression: 0.518 (+/- 0.011)
# LogisticRegression+(1,2)gram: 0.517 (+/- 0.011)
# LogisticRegression+preprocess: 0.524 (+/- 0.010)
# LogisticRegression+preprocess+hash: 0.524 (+/- 0.010)

# %%
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, VotingClassifier

print('[Voting]')
best_vt, best_w, best_score = None, (), -1
for a, b, c, d in list(itertools.permutations(range(0,4))): # try some weight combination
    clf = VotingClassifier(estimators=[('LogisticRegression', pipe1), ('LogisticRegression+(1,2)gram', pipe2), 
                                       ('LogisticRegression+preprocess', pipe3), ('LogisticRegression+preprocess+hash', pipe4)], 
                           voting='soft', weights=[a,b,c,d])
    scores = cross_val_score(estimator=clf, X=np.array(headline), y=df['Popularity'], cv=10, scoring='roc_auc')
    print('%s: %.3f (+/- %.3f)' % ((a,b,c,d), scores.mean(), scores.std()))
    if best_score < scores.mean():
        best_vt, best_w, best_score = clf, (a, b, c, d), scores.mean()

print('\nBest %s: %.3f' % (best_w, best_score))
# Out:
# [Voting]
# (0, 1, 2, 3): 0.523 (+/- 0.009)
# (0, 1, 3, 2): 0.524 (+/- 0.010)
# (0, 2, 1, 3): 0.522 (+/- 0.010)
# (0, 2, 3, 1): 0.522 (+/- 0.010)
# (0, 3, 1, 2): 0.520 (+/- 0.010)
# (0, 3, 2, 1): 0.520 (+/- 0.011)
# (1, 0, 2, 3): 0.523 (+/- 0.009)
# (1, 0, 3, 2): 0.524 (+/- 0.010)
# (1, 2, 0, 3): 0.521 (+/- 0.010)
# (1, 2, 3, 0): 0.521 (+/- 0.011)
# (1, 3, 0, 2): 0.519 (+/- 0.010)
# (1, 3, 2, 0): 0.519 (+/- 0.011)
# (2, 0, 1, 3): 0.522 (+/- 0.010)
# (2, 0, 3, 1): 0.522 (+/- 0.010)
# (2, 1, 0, 3): 0.521 (+/- 0.010)
# (2, 1, 3, 0): 0.521 (+/- 0.011)
# (2, 3, 0, 1): 0.519 (+/- 0.011)
# (2, 3, 1, 0): 0.519 (+/- 0.011)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-04f1b6aae0b6> in <module>
#       7                                        ('LogisticRegression+preprocess', pipe3), ('LogisticRegression+preprocess+hash', pipe4)],
#       8                            voting='soft', weights=[a,b,c,d])
# ----> 9     scores = cross_val_score(estimator=clf, X=np.array(headline), y=df['Popularity'], cv=10, scoring='roc_auc')
#      10     print('%s: %.3f (+/- %.3f)' % ((a,b,c,d), scores.mean(), scores.std()))
#      11     if best_score < scores.mean():
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
#     390                                 pre_dispatch=pre_dispatch,
# --> 391                                 error_score=error_score)
#     392     return cv_results['test_score']
#     393
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     230             return_times=True, return_estimator=return_estimator,
#     231             error_score=error_score)
# --> 232         for train, test in cv.split(X, y, groups))
#     233
#     234     zipped_scores = list(zip(*scores))
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\ensemble\voting.py in fit(self, X, y, sample_weight)
#     277         transformed_y = self.le_.transform(y)
#     278
# --> 279         return super().fit(X, transformed_y, sample_weight)
#     280
#     281     def predict(self, X):
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\ensemble\voting.py in fit(self, X, y, sample_weight)
#      99                 delayed(_parallel_fit_estimator)(clone(clf), X, y,
#     100                                                  sample_weight=sample_weight)
# --> 101                 for clf in clfs if clf not in (None, 'drop')
#     102             )
#     103
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\ensemble\voting.py in _parallel_fit_estimator(estimator, X, y, sample_weight)
#      41             raise
#      42     else:
# ---> 43         estimator.fit(X, y)
#      44     return estimator
#      45
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     350             This estimator
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#     354                                  self._log_message(len(self.steps) - 1)):
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# ~\.conda\envs\tf2\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# ~\.conda\envs\tf2\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     981             j_indices.extend(feature_counter.keys())
#     982             values.extend(feature_counter.values())
# --> 983             indptr.append(len(j_indices))
#     984
#     985         if not fixed_vocab:
#
# KeyboardInterrupt:
